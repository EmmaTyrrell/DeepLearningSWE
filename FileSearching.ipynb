# %%
# import modules
import pandas as pd
import os
import zipfile
import shutil
import tempfile
print("import modules")

# list file paths 
years = list(range(2025, 2026))
domain = "Rockies"
WW_asoDir = r"W:/Spatial_SWE/ASO/"
SNM_asoDir = r"J:/Spatial_SWE/ASO/"
print("file paths established")

for year in years:
    aso_dir = f"{WW_asoDir}/{year}/"
    extensions = ("snowdepth_3m.tif", "swe_50m.tif")
    
    # create an if then statement on if a year folder exists, dont create it, if not, create it, 
    folder_path = f"D:/ASOML/{domain}/{year}/"
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)  
        print(f"Created folder: {folder_path}")
    else:
        print(f"Folder already exists: {folder_path}")
        
    # check for snow dpeth and create that folder
    sd_path = folder_path + "SD/"
    if not os.path.exists(sd_path):
        os.makedirs(sd_path)  
        print(f"Created folder: {sd_path}")
    else:
        print(f"Folder already exists: {sd_path}")

    # check for swe and create that folder
    swe_path = folder_path + "SWE/"
    if not os.path.exists(swe_path):
        os.makedirs(swe_path)  
        print(f"Created folder: {swe_path}")
    else:
        print(f"Folder already exists: {swe_path}")

    # make a list of all zip files and loops through them
    zip_files = [f for f in os.listdir(aso_dir) if f.endswith(".zip")]

    for zip_filename in zip_files:
        zip_path = os.path.join(aso_dir, zip_filename)  # Full path to ZIP file
        print(" ")
        print(f"Processing ZIP file: {zip_path}")
        
        with zipfile.ZipFile(zip_path, 'r') as zip_file:
            matching_files = [file for file in zip_file.namelist() if file.endswith(extensions)]
            print("Files ending with", extensions, ":", matching_files)

            for file in matching_files:
                    # # Determine destination based on file extension
                    # if file.endswith("/"):  
                    #     print(f"Skipping directory: {file}")
                    #     continue  
                    if file.endswith("snowdepth_3m.tif"):
                        extract_path = os.path.join(sd_path, os.path.basename(file))
                    elif file.endswith("swe_50m.tif"):
                        extract_path = os.path.join(swe_path, os.path.basename(file)) 

                    # Extract from zip and write to destination
                    try:
                        with zip_file.open(file) as source, open(extract_path, 'wb') as target:
                            shutil.copyfileobj(source, target)
                        print(f"Extracted {file} to {extract_path}")
                    except Exception as e:
                        print(f"Failed to extract {file}: {e}")
    print(f"done with {year}")
    print(" ")
# Out:
# import modules
# file paths established
# Folder already exists: D:/ASOML/Rockies/2025/
# Folder already exists: D:/ASOML/Rockies/2025/SD/
# Folder already exists: D:/ASOML/Rockies/2025/SWE/
#
# Processing ZIP file: W:/Spatial_SWE/ASO//2025/ASO_Kaweah_2025Jan16_AllData_and_Reports.zip
# Files ending with ('snowdepth_3m.tif', 'swe_50m.tif') : ['ASO_Kaweah_2025Jan16_swe_50m.tif', 'ASO_Kaweah_2025Jan16_snowdepth_3m.tif']
# Extracted ASO_Kaweah_2025Jan16_swe_50m.tif to D:/ASOML/Rockies/2025/SWE/ASO_Kaweah_2025Jan16_swe_50m.tif
# Extracted ASO_Kaweah_2025Jan16_snowdepth_3m.tif to D:/ASOML/Rockies/2025/SD/ASO_Kaweah_2025Jan16_snowdepth_3m.tif
#
# Processing ZIP file: W:/Spatial_SWE/ASO//2025/ASO_Feather_2025Jan27-29_AllData_and_Reports.zip
# Files ending with ('snowdepth_3m.tif', 'swe_50m.tif') : ['ASO_Feather_2025Jan27-29_swe_50m.tif', 'ASO_Feather_2025Jan27-29_snowdepth_3m.tif']
# Extracted ASO_Feather_2025Jan27-29_swe_50m.tif to D:/ASOML/Rockies/2025/SWE/ASO_Feather_2025Jan27-29_swe_50m.tif
# Extracted ASO_Feather_2025Jan27-29_snowdepth_3m.tif to D:/ASOML/Rockies/2025/SD/ASO_Feather_2025Jan27-29_snowdepth_3m.tif
#
# Processing ZIP file: W:/Spatial_SWE/ASO//2025/ASO_Kings_2025Jan28-30_AllData_and_Reports.zip
# Files ending with ('snowdepth_3m.tif', 'swe_50m.tif') : ['ASO_Kings_2025Jan28-30_swe_50m.tif', 'ASO_Kings_2025Jan28-30_snowdepth_3m.tif']
# Extracted ASO_Kings_2025Jan28-30_swe_50m.tif to D:/ASOML/Rockies/2025/SWE/ASO_Kings_2025Jan28-30_swe_50m.tif
# Extracted ASO_Kings_2025Jan28-30_snowdepth_3m.tif to D:/ASOML/Rockies/2025/SD/ASO