# %%
# this is a QC to check to make sure everything has the right size
import rasterio
import os
import pandas
import numpy as np

years = list(range(2024, 2025))
for year in years:
    print(f"Processing {year}")
    folder = f"D:/ASOML/Sierras/{year}/SWE_processed_splits/"
    for file in os.listdir(folder):
        if file.endswith("nonull.tif"):
            raster_path = os.path.join(folder, file)
            with rasterio.open(raster_path) as src:
                shape = src.read(1).shape
                data = src.read(1)
                data[data == -9999] = -1
                if shape != (256, 256):
                    print(f"{file} | {shape} | {year}")
                    # fix the raster paths 
                    fixed_data = np.full((256, 256), -1, dtype=data.dtype)
                    # Paste the original data into the top-left corner
                    fixed_data[:shape[0], :shape[1]] = data
                else:
                    fixed_data = data 

                # Update metadata
                new_meta = src.meta.copy()
                new_meta.update({
                    'height': 256,
                    'width': 256,
                    'nodata': -1,
                    'transform': rasterio.transform.from_origin(
                        src.bounds.left, src.bounds.top,
                        src.res[0], src.res[1]
                    )
                })

                # Overwrite the original raster
                with rasterio.open(f"{raster_path[:-4]}_fnl.tif", 'w', **new_meta) as dst:
                    dst.write(fixed_data, 1)

for year in years: 
    folder = f"D:/ASOML/Sierras/{year}/SWE_processed_splits/"
    for filename in os.listdir(folder):
        if not filename.endswith("_fnl.tif"):
            file_path = os.path.join(folder, filename)
            if os.path.isfile(file_path):  
                # print(f"Deleting: {file_path}")
                os.remove(file_path)
# Out:
# Processing 2024
# Carson_2024053_albn83_60m_SWE37_nonull.tif | (173, 256) | 2024
# Carson_2024053_albn83_60m_SWE38_nonull.tif | (173, 256) | 2024
# Carson_2024081_albn83_60m_SWE37_nonull.tif | (173, 256) | 2024
# Carson_2024081_albn83_60m_SWE38_nonull.tif | (173, 256) | 2024
# Carson_2024108_albn83_60m_SWE37_nonull.tif | (173, 256) | 2024
# Carson_2024108_albn83_60m_SWE38_nonull.tif | (173, 256) | 2024
# Carson_2024137_albn83_60m_SWE37_nonull.tif | (173, 256) | 2024
# Carson_2024137_albn83_60m_SWE38_nonull.tif | (173, 256) | 2024
# Carson_2024159_albn83_60m_SWE37_nonull.tif | (173, 256) | 2024
# Feather_2024053_albn83_60m_SWE122_nonull.tif | (132, 256) | 2024
# Feather_2024053_albn83_60m_SWE123_nonull.tif | (132, 256) | 2024
# Feather_2024075_albn83_60m_SWE122_nonull.tif | (132, 256) | 2024
# Feather_2024075_albn83_60m_SWE123_nonull.tif | (132, 256) | 2024
# Feather_2024107_albn83_60m_SWE122_nonull.tif | (132, 256) | 2024
# Feather_2024107_albn83_60m_SWE123_nonull.tif | (132, 256) | 2024
# Feather_2024134_albn83_60m_SWE122_nonull.tif | (132, 256) | 2024
# Feather_2024134_albn83_60m_SWE123_nonull.tif | (132, 256) | 2024
# Kaweah_2024042_albn83_60m_SWE11_nonull.tif | (256, 215) | 2024
# Kaweah_2024042_albn83_60m_SWE15_nonull.tif | (256, 215) | 2024
# Kaweah_2024042_albn83_60m_SWE17_nonull.tif | (73, 256) | 2024
# Kaweah_2024042_albn83_60m_SWE3_nonull.tif | (256, 215) | 2024
# Kaweah_2024042_albn83_60m_SWE7_nonull.tif | (256, 215) | 2024
# Kaweah_2024094_albn83_60m_SWE11_nonull.tif | (256, 215) | 2024
# Kaweah_2024094_albn83_60m_SWE15_nonull.tif | (256, 215) | 2024
# Kaweah_2024094_albn83_60m_SWE17_nonull.tif | (73, 256) | 2024
# Kaweah_2024094_albn83_60m_SWE3_nonull.tif | (256, 215) | 2024
# Kaweah_2024094_albn83_60m_SWE7_nonull.tif | (256, 215) | 2024
# Kaweah_2024119_albn83_60m_SWE11_nonull.tif | (256, 215) | 2024
# Kaweah_2024119_albn83_60m_SWE15_nonull.tif | (256, 215) | 2024
# Kaweah_2024119_albn83_60m_SWE17_nonull.tif | (73, 256) | 2024
# Kaweah_2024119_albn83_60m_SWE3_nonull.tif | (256, 215) | 2024
# Kaweah_2024119_albn83_60m_SWE7_nonull.tif | (256, 215) | 2024
# Kaweah_2024141_albn83_60m_SWE11_nonull.tif | (256, 215) | 2024
# Kaweah_2024141_albn83_60m_SWE15_nonull.tif | (256, 215) | 2024
# Kaweah_2024141_albn83_60m_SWE17_nonull.tif | (73, 256) | 2024
# Kaweah_2024141_albn83_60m_SWE3_nonull.tif | (256, 215) | 2024
# Kaweah_2024141_albn83_60m_SWE7_nonull.tif | (256, 215) | 2024
# Kern_2024041_albn83_60m_SWE50_nonull.tif | (209, 256) | 2024
# Kern_2024041_albn83_60m_SWE51_nonull.tif | (209, 256) | 2024
# Kern_2024102_albn83_60m_SWE50_nonull.tif | (209, 256) | 2024
# Kern_2024102_albn83_60m_SWE51_nonull.tif | (209, 256) | 2024
# Kern_2024129_albn83_60m_SWE50_nonull.tif | (209, 256) | 2024
# Kern_2024129_albn83_60m_SWE51_nonull.tif | (209, 256) | 2024
# Kings_2024027_albn83_60m_SWE15_nonull.tif | (256, 251) | 2024
# Kings_2024027_albn83_60m_SWE23_nonull.tif | (256, 251) | 2024
# Kings_2024027_albn83_60m_SWE31_nonull.tif | (256, 251) | 2024
# Kings_2024027_albn83_60m_SWE39_nonull.tif | (256, 251) | 2024
# Kings_2024027_albn83_60m_SWE7_nonull.tif | (256, 251) | 2024
# Kings_2024068_albn83_60m_SWE15_nonull.tif | (256, 251) | 2024
# Kings_2024068_albn83_60m_SWE23_nonull.tif | (256, 251) | 2024
# Kings_2024068_albn83_60m_SWE31_nonull.tif | (256, 251) | 2024
# Kings_2024068_albn83_60m_SWE39_nonull.tif | (256, 251) | 2024
# Kings_2024068_albn83_60m_SWE7_nonull.tif | (256, 251) | 2024
# Kings_2024101_albn83_60m_SWE15_nonull.tif | (256, 251) | 2024
# Kings_2024101_albn83_60m_SWE23_nonull.tif | (256, 251) | 2024
# Kings_2024101_albn83_60m_SWE31_nonull.tif | (256, 251) | 2024
# Kings_2024101_albn83_60m_SWE39_nonull.tif | (256, 251) | 2024
# Kings_2024101_albn83_60m_SWE7_nonull.tif | (256, 251) | 2024
# Kings_2024118_albn83_60m_SWE15_nonull.tif | (256, 251) | 2024
# Kings_2024118_albn83_60m_SWE23_nonull.tif | (256, 251) | 2024
# Kings_2024118_albn83_60m_SWE31_nonull.tif | (256, 251) | 2024
# Kings_2024118_albn83_60m_SWE39_nonull.tif | (256, 251) | 2024
# Kings_2024118_albn83_60m_SWE7_nonull.tif | (256, 251) | 2024
# Merced_2024043_albn83_60m_SWE11_nonull.tif | (256, 144) | 2024
# Merced_2024043_albn83_60m_SWE17_nonull.tif | (256, 144) | 2024
# Merced_2024043_albn83_60m_SWE24_nonull.tif | (181, 256) | 2024
# Merced_2024043_albn83_60m_SWE27_nonull.tif | (181, 256) | 2024
# Merced_2024068_albn83_60m_SWE11_nonull.tif | (256, 144) | 2024
# Merced_2024068_albn83_60m_SWE17_nonull.tif | (256, 144) | 2024
# Merced_2024068_albn83_60m_SWE24_nonull.tif | (181, 256) | 2024
# Merced_2024068_albn83_60m_SWE27_nonull.tif | (181, 256) | 2024
# Merced_2024100_albn83_60m_SWE11_nonull.tif | (256, 144) | 2024
# Merced_2024100_albn83_60m_SWE17_nonull.tif | (256, 144) | 2024
# Merced_2024100_albn83_60m_SWE24_nonull.tif | (181, 256) | 2024
# Merced_2024100_albn83_60m_SWE27_nonull.tif | (181, 256) | 2024
# Merced_2024123_albn83_60m_SWE11_nonull.tif | (256, 144) | 2024
# Merced_2024123_albn83_60m_SWE17_nonull.tif | (256, 144) | 2024
# Merced_2024123_albn83_60m_SWE24_nonull.tif | (181, 256) | 2024
# Merced_2024123_albn83_60m_SWE27_nonull.tif | (181, 256) | 2024
# Merced_2024144_albn83_60m_SWE11_nonull.tif | (256, 144) | 2024
# Merced_2024144_albn83_60m_SWE17_nonull.tif | (256, 144) | 2024
# Merced_2024144_albn83_60m_SWE27_nonull.tif | (181, 256) | 2024
# Tuolumne_2024029_albn83_60m_SWE15_nonull.tif | (256, 166) | 2024
# Tuolumne_2024058_albn83_60m_SWE15_nonull.tif | (256, 166) | 2024
# Tuolumne_2024093_albn83_60m_SWE15_nonull.tif | (256, 166) | 2024
# Tuolumne_2024122_albn83_60m_SWE15_nonull.tif | (256, 166) | 2024
# Yuba_2024041_albn83_60m_SWE5_nonull.tif | (256, 254) | 2024
# Yuba_2024058_albn83_60m_SWE5_nonull.tif | (256, 254) | 2024
# Yuba_2024092_albn83_60m_SWE5_nonull.tif | (256, 254) | 2024
# Yuba_2024120_albn83_60m_SWE5_nonull.tif | (256, 254) | 2024
# Yuba_2024148_albn83_60m_SWE5_nonull.tif | (256, 254) | 2024

# %%
import os 
lst = os.listdir(f"D:/ASOML/Sierras/2024/SWE_processed_splits_50/")

# %%
len(lst)
# Out:
# 4161
