# %%
# this is a QC to check to make sure everything has the right size
import rasterio
import os
import pandas
import numpy as np

years = list(range(2025, 2026))
for year in years:
    print(f"Processing {year}")
    folder = f"D:/ASOML/Rockies/{year}/SWE_processed_splits/"
    for file in os.listdir(folder):
        if file.endswith("nonull.tif"):
            raster_path = os.path.join(folder, file)
            with rasterio.open(raster_path) as src:
                shape = src.read(1).shape
                data = src.read(1)
                data[data == -9999] = -1
                if shape != (256, 256):
                    print(f"{file} | {shape} | {year}")
                    # fix the raster paths 
                    fixed_data = np.full((256, 256), -1, dtype=data.dtype)
                    # Paste the original data into the top-left corner
                    fixed_data[:shape[0], :shape[1]] = data
                else:
                    fixed_data = data 

                # Update metadata
                new_meta = src.meta.copy()
                new_meta.update({
                    'height': 256,
                    'width': 256,
                    'nodata': -1,
                    'transform': rasterio.transform.from_origin(
                        src.bounds.left, src.bounds.top,
                        src.res[0], src.res[1]
                    )
                })

                # Overwrite the original raster
                with rasterio.open(f"{raster_path[:-4]}_fnl_2.tif", 'w', **new_meta) as dst:
                    dst.write(fixed_data, 1)
# Out:
# Processing 2025
# BigThompson_2025101_albn83_60m_SWE10_nonull.tif | (161, 256) | 2025
# BigThompson_2025101_albn83_60m_SWE3_nonull.tif | (256, 130) | 2025
# BigThompson_2025101_albn83_60m_SWE7_nonull.tif | (256, 130) | 2025
# BigThompson_2025101_albn83_60m_SWE8_nonull.tif | (161, 256) | 2025
# BigThompson_2025101_albn83_60m_SWE9_nonull.tif | (161, 256) | 2025
# BlueRiver_2025101_albn83_60m_SWE2_nonull.tif | (256, 239) | 2025
# BlueRiver_2025101_albn83_60m_SWE5_nonull.tif | (256, 239) | 2025
# BlueRiver_2025101_albn83_60m_SWE6_nonull.tif | (148, 256) | 2025
# BlueRiver_2025101_albn83_60m_SWE7_nonull.tif | (148, 256) | 2025
# BlueRiver_2025101_albn83_60m_SWE8_nonull.tif | (148, 239) | 2025
# BoulderCreek_2025099_albn83_60m_SWE2_nonull.tif | (256, 129) | 2025
# BoulderCreek_2025099_albn83_60m_SWE3_nonull.tif | (220, 256) | 2025
# BoulderCreek_2025099_albn83_60m_SWE4_nonull.tif | (220, 256) | 2025
# BoulderCreek_2025099_albn83_60m_SWE5_nonull.tif | (220, 129) | 2025
# ClearCreek_2025099_albn83_60m_SWE11_nonull.tif | (119, 256) | 2025
# ClearCreek_2025099_albn83_60m_SWE12_nonull.tif | (119, 256) | 2025
# Conejos_2025080_albn83_60m_SWE3_nonull.tif | (256, 84) | 2025
# Conejos_2025118_albn83_60m_SWE3_nonull.tif | (256, 84) | 2025
# Dolores_2025096_albn83_60m_SWE16_nonull.tif | (164, 256) | 2025
# Dolores_2025096_albn83_60m_SWE17_nonull.tif | (164, 256) | 2025
# Dolores_2025096_albn83_60m_SWE18_nonull.tif | (164, 256) | 2025
# Dolores_2025117_albn83_60m_SWE16_nonull.tif | (164, 256) | 2025
# Dolores_2025117_albn83_60m_SWE17_nonull.tif | (164, 256) | 2025
# Dolores_2025117_albn83_60m_SWE18_nonull.tif | (164, 256) | 2025
# EastRiver_2025097_albn83_60m_SWE5_nonull.tif | (256, 94) | 2025
# EastRiver_2025097_albn83_60m_SWE6_nonull.tif | (240, 256) | 2025
# EastRiver_2025097_albn83_60m_SWE7_nonull.tif | (240, 256) | 2025
# EastRiver_2025097_albn83_60m_SWE8_nonull.tif | (240, 94) | 2025
# GunnisonNorth_2025086_albn83_60m_SWE11_nonull.tif | (256, 244) | 2025
# GunnisonNorth_2025086_albn83_60m_SWE17_nonull.tif | (105, 256) | 2025
# GunnisonNorth_2025086_albn83_60m_SWE18_nonull.tif | (105, 256) | 2025
# GunnisonNorth_2025086_albn83_60m_SWE3_nonull.tif | (256, 244) | 2025
# GunnisonNorth_2025086_albn83_60m_SWE7_nonull.tif | (256, 244) | 2025
# GunnisonNorth_2025117_albn83_60m_SWE11_nonull.tif | (256, 244) | 2025
# GunnisonNorth_2025117_albn83_60m_SWE17_nonull.tif | (105, 256) | 2025
# GunnisonNorth_2025117_albn83_60m_SWE18_nonull.tif | (105, 256) | 2025
# GunnisonNorth_2025117_albn83_60m_SWE3_nonull.tif | (256, 244) | 2025
# GunnisonNorth_2025117_albn83_60m_SWE7_nonull.tif | (256, 244) | 2025
# Poudre_2025097_albn83_60m_SWE10_nonull.tif | (254, 256) | 2025
# Poudre_2025097_albn83_60m_SWE8_nonull.tif | (254, 256) | 2025
# Poudre_2025097_albn83_60m_SWE9_nonull.tif | (254, 256) | 2025
# RioGrande_2025082_albn83_60m_SWE13_nonull.tif | (256, 153) | 2025
# RioGrande_2025082_albn83_60m_SWE20_nonull.tif | (256, 153) | 2025
# RioGrande_2025082_albn83_60m_SWE27_nonull.tif | (256, 153) | 2025
# RioGrande_2025082_albn83_60m_SWE29_nonull.tif | (193, 256) | 2025
# RioGrande_2025082_albn83_60m_SWE30_nonull.tif | (193, 256) | 2025
# RioGrande_2025082_albn83_60m_SWE31_nonull.tif | (193, 256) | 2025
# RioGrande_2025082_albn83_60m_SWE32_nonull.tif | (193, 256) | 2025
# RoaringFork_2025102_albn83_60m_SWE11_nonull.tif | (256, 73) | 2025
# RoaringFork_2025102_albn83_60m_SWE13_nonull.tif | (215, 256) | 2025
# RoaringFork_2025102_albn83_60m_SWE14_nonull.tif | (215, 256) | 2025
# RoaringFork_2025102_albn83_60m_SWE15_nonull.tif | (215, 73) | 2025
# RoaringFork_2025102_albn83_60m_SWE7_nonull.tif | (256, 73) | 2025
# SouthPlatte_2025100_albn83_60m_SWE14_nonull.tif | (256, 254) | 2025
# SouthPlatte_2025100_albn83_60m_SWE19_nonull.tif | (256, 254) | 2025
# SouthPlatte_2025100_albn83_60m_SWE24_nonull.tif | (256, 254) | 2025
# SouthPlatte_2025100_albn83_60m_SWE27_nonull.tif | (151, 256) | 2025
# SouthPlatte_2025100_albn83_60m_SWE28_nonull.tif | (151, 256) | 2025
# StVrainLefthand_2025101_albn83_60m_SWE2_nonull.tif | (256, 130) | 2025
# StVrainLefthand_2025101_albn83_60m_SWE5_nonull.tif | (256, 130) | 2025
# StVrainLefthand_2025101_albn83_60m_SWE6_nonull.tif | (28, 256) | 2025
# StVrainLefthand_2025101_albn83_60m_SWE7_nonull.tif | (28, 256) | 2025
# Taylor_2025097_albn83_60m_SWE2_nonull.tif | (256, 245) | 2025
# Taylor_2025097_albn83_60m_SWE5_nonull.tif | (256, 245) | 2025
# UintaMountains_2025084_albn83_60m_SWE29_nonull.tif | (256, 50) | 2025
# UintaMountains_2025084_albn83_60m_SWE32_nonull.tif | (230, 256) | 2025
# UintaMountains_2025084_albn83_60m_SWE33_nonull.tif | (230, 256) | 2025
# UintaMountains_2025084_albn83_60m_SWE34_nonull.tif | (230, 256) | 2025
# UintaMountains_2025104_albn83_60m_SWE29_nonull.tif | (256, 50) | 2025
# UintaMountains_2025104_albn83_60m_SWE32_nonull.tif | (230, 256) | 2025
# UintaMountains_2025104_albn83_60m_SWE33_nonull.tif | (230, 256) | 2025
# UintaMountains_2025104_albn83_60m_SWE34_nonull.tif | (230, 256) | 2025
# WindyGap_2025097_albn83_60m_SWE11_nonull.tif | (256, 92) | 2025
# WindyGap_2025097_albn83_60m_SWE15_nonull.tif | (256, 92) | 2025
# WindyGap_2025097_albn83_60m_SWE21_nonull.tif | (101, 256) | 2025
# WindyGap_2025097_albn83_60m_SWE22_nonull.tif | (101, 256) | 2025
# WindyGap_2025119_albn83_60m_SWE11_nonull.tif | (256, 92) | 2025
# WindyGap_2025119_albn83_60m_SWE15_nonull.tif | (256, 92) | 2025
# WindyGap_2025119_albn83_60m_SWE21_nonull.tif | (101, 256) | 2025
# WindyGap_2025119_albn83_60m_SWE22_nonull.tif | (101, 256) | 2025
# YampaRiver_2025101_albn83_60m_SWE11_nonull.tif | (256, 235) | 2025
# YampaRiver_2025101_albn83_60m_SWE15_nonull.tif | (256, 235) | 2025
# YampaRiver_2025101_albn83_60m_SWE19_nonull.tif | (256, 235) | 2025
# YampaRiver_2025101_albn83_60m_SWE23_nonull.tif | (256, 235) | 2025
# YampaRiver_2025101_albn83_60m_SWE27_nonull.tif | (256, 235) | 2025
# YampaRiver_2025101_albn83_60m_SWE7_nonull.tif | (256, 235) | 2025
